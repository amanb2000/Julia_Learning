# %%
using Images, Plots, TestImages
using ImageShow
using Colors
using Statistics
using FileIO
using LinearAlgebra

# %%
# Some Governing Constants

im_dims = (80, 80)
typeof(im_dims)
# Out:
# Tuple{Int64,Int64}

# %%
# Function for getting an nxm matrix from an image path.

function get_bw_img_arry(path, im_dims)
    image = imresize(load(path), im_dims)

    chan = channelview(image)[1,:,:]
    return chan
end

function back_to_2d(image_arry, im_dims)
    return reshape(image_arry, im_dims)
end

function get_max_1(image_arry)
    return (image_arry/maximum(image_arry))
end
# Out:
# get_max_1 (generic function with 1 method)

# %%
base_path = "images/lfw/";
file = open(string(base_path,"filenames.txt"));
image_names = readlines(file);

# %%
images = zeros(length(image_names), im_dims[1], im_dims[2]);
average_face = zeros(im_dims)

for i = 1:length(image_names)
    global images[i,:,:] = get_bw_img_arry(string(base_path,image_names[i],"/",image_names[i],"_0001.jpg"), im_dims);
    global average_face += images[i,:,:]/length(image_names);
end

# Vectorizing

images = reshape(images, (size(images,1), im_dims[1]*im_dims[2]))

size(images)
# Out:
# (5749, 6400)

# %%
# Gray.(back_to_2d(images[2,:])) # Outputting the average face.
avg_face = sum(images, dims=1)/size(images, 1)
# avg_face = back_to_2d(avg_face, im_dims)
Gray.(back_to_2d(avg_face, im_dims))
# Out:
# 80×80 Array{Gray{Float64},2} with eltype Gray{Float64}:
#  Gray{Float64}(0.234117)  Gray{Float64}(0.238315)  …  Gray{Float64}(0.23562)
#  Gray{Float64}(0.251927)  Gray{Float64}(0.255596)     Gray{Float64}(0.253791)
#  Gray{Float64}(0.27042)   Gray{Float64}(0.274655)     Gray{Float64}(0.271662)
#  Gray{Float64}(0.292469)  Gray{Float64}(0.296659)     Gray{Float64}(0.294929)
#  Gray{Float64}(0.313062)  Gray{Float64}(0.316629)     Gray{Float64}(0.314966)
#  Gray{Float64}(0.332437)  Gray{Float64}(0.336091)  …  Gray{Float64}(0.334884)
#  Gray{Float64}(0.348333)  Gray{Float64}(0.353174)     Gray{Float64}(0.351981)
#  Gray{Float64}(0.36523)   Gray{Float64}(0.371351)     Gray{Float64}(0.368492)
#  Gray{Float64}(0.375578)  Gray{Float64}(0.383066)     Gray{Float64}(0.380044)
#  Gray{Float64}(0.380472)  Gray{Float64}(0.387705)     Gray{Float64}(0.384476)
#  Gray{Float64}(0.38572)   Gray{Float64}(0.392399)  …  Gray{Float64}(0.387779)
#  Gray{Float64}(0.389934)  Gray{Float64}(0.396654)     Gray{Float64}(0.391911)
#  Gray{Float64}(0.39299)   Gray{Float64}(0.399422)     Gray{Float64}(0.394274)
#  ⋮                                                 ⋱
#  Gray{Float64}(0.37023)   Gray{Float64}(0.374902)     Gray{Float64}(0.355328)
#  Gray{Float64}(0.365473)  Gray{Float64}(0.369962)     Gray{Float64}(0.354783)
#  Gray{Float64}(0.362821)  Gray{Float64}(0.369056)  …  Gray{Float64}(0.35084)
#  Gray{Float64}(0.362471)  Gray{Float64}(0.367466)     Gray{Float64}(0.350001)
#  Gray{Float64}(0.359376)  Gray{Float64}(0.364979)     Gray{Float64}(0.347779)
#  Gray{Float64}(0.354227)  Gray{Float64}(0.359647)     Gray{Float64}(0.345234)
#  Gray{Float64}(0.351332)  Gray{Float64}(0.355784)     Gray{Float64}(0.342786)
#  Gray{Float64}(0.347017)  Gray{Float64}(0.352304)  …  Gray{Float64}(0.338613)
#  Gray{Float64}(0.344424)  Gray{Float64}(0.349005)     Gray{Float64}(0.336603)
#  Gray{Float64}(0.342957)  Gray{Float64}(0.347293)     Gray{Float64}(0.333572)
#  Gray{Float64}(0.339338)  Gray{Float64}(0.344011)     Gray{Float64}(0.331538)
#  Gray{Float64}(0.337751)  Gray{Float64}(0.340646)     Gray{Float64}(0.330774)

# %%
normed_faces = copy(images)

println("Average face [1]: ",avg_face[10])
avg_face = reshape(avg_face, (im_dims[1]*im_dims[2]))
println("Average face [1]: ",avg_face[10])

for i = 1:size(images,1)
    normed_faces[i,:] = images[i,:]-avg_face
end

Gray.(back_to_2d(normed_faces[1000,:], im_dims))
# Out:
# Average face [1]: 0.3804719661390386
# Average face [1]: 0.3804719661390386
# 80×80 Array{Gray{Float64},2} with eltype Gray{Float64}:
#  Gray{Float64}(-0.234117)  …  Gray{Float64}(-0.23562)
#  Gray{Float64}(-0.251927)     Gray{Float64}(-0.253791)
#  Gray{Float64}(-0.27042)      Gray{Float64}(-0.271662)
#  Gray{Float64}(-0.292469)     Gray{Float64}(-0.294929)
#  Gray{Float64}(-0.313062)     Gray{Float64}(-0.314966)
#  Gray{Float64}(-0.328515)  …  Gray{Float64}(-0.334884)
#  Gray{Float64}(-0.167941)     Gray{Float64}(-0.257864)
#  Gray{Float64}(-0.137779)     Gray{Float64}(-0.243002)
#  Gray{Float64}(-0.148127)     Gray{Float64}(-0.258476)
#  Gray{Float64}(-0.149099)     Gray{Float64}(-0.258986)
#  Gray{Float64}(-0.154348)  …  Gray{Float64}(-0.26621)
#  Gray{Float64}(-0.15464)      Gray{Float64}(-0.286028)
#  Gray{Float64}(-0.16946)      Gray{Float64}(-0.276626)
#  ⋮                         ⋱
#  Gray{Float64}(-0.232975)     Gray{Float64}(-0.131799)
#  Gray{Float64}(-0.228218)     Gray{Float64}(-0.131254)
#  Gray{Float64}(-0.225566)  …  Gray{Float64}(-0.123389)
#  Gray{Float64}(-0.233059)     Gray{Float64}(-0.138236)
#  Gray{Float64}(-0.222121)     Gray{Float64}(-0.147779)
#  Gray{Float64}(-0.220894)     Gray{Float64}(-0.156998)
#  Gray{Float64}(-0.229763)     Gray{Float64}(-0.150629)
#  Gray{Float64}(-0.221527)  …  Gray{Float64}(-0.154299)
#  Gray{Float64}(-0.203248)     Gray{Float64}(-0.179741)
#  Gray{Float64}(-0.229231)     Gray{Float64}(-0.141415)
#  Gray{Float64}(-0.19424)      Gray{Float64}(-0.119773)
#  Gray{Float64}(-0.137751)     Gray{Float64}(-0.103323)

# %%
cov_mat = cov(normed_faces, dims=1)
size(cov_mat)
# Out:
# (6400, 6400)

# %%
F = eigen(cov_mat)
# Out:
# Eigen{Float64,Float64,Array{Float64,2},Array{Float64,1}}
Array{Gray{Float64},2} with eltype Gray{Float64}:
#  Gray{Float64}(0.5981)    Gray{Float64}(0.611612)  …  Gray{Float64}(0.606594)
#  Gray{Float64}(0.650466)  Gray{Float64}(0.661325)     Gray{Float64}(0.65786)
#  Gray{Float64}(0.694255)  Gray{Float64}(0.706097)     Gray{Float64}(0.694918)
#  Gray{Float64}(0.746073)  Gray{Float64}(0.758883)     Gray{Float64}(0.740343)
#  Gray{Float64}(0.780373)  Gray{Float64}(0.792887)     Gray{Float64}(0.779172)
#  Gray{Float64}(0.817479)  Gray{Float64}(0.834212)  …  Gray{Float64}(0.818948)
#  Gray{Float64}(0.836837)  Gray{Float64}(0.85408)      Gray{Float64}(0.839601)
#  Gray{Float64}(0.855095)  Gray{Float64}(0.876048)     Gray{Float64}(0.857549)
#  Gray{Float64}(0.864459)  Gray{Float64}(0.887318)     Gray{Float64}(0.865371)
#  Gray{Float64}(0.86219)   Gray{Float64}(0.887248)     Gray{Float64}(0.870515)
#  Gray{Float64}(0.860256)  Gray{Float64}(0.886036)  …  Gray{Float64}(0.870827)
#  Gray{Float64}(0.863998)  Gray{Float64}(0.890547)     Gray{Float64}(0.870999)
#  Gray{Float64}(0.861068)  Gray{Float64}(0.888853)     Gray{Float64}(0.871723)
#  ⋮                                                 ⋱
#  Gray{Float64}(0.495642)  Gray{Float64}(0.493724)     Gray{Float64}(0.437891)
#  Gray{Float64}(0.468822)  Gray{Float64}(0.464651)     Gray{Float64}(0.421431)
#  Gray{Float64}(0.447251)  Gray{Float64}(0.446178)  …  Gray{Float64}(0.401531)
#  Gray{Float64}(0.425657)  Gray{Float64}(0.425685)     Gray{Float64}(0.387376)
#  Gray{Float64}(0.412465)  Gray{Float64}(0.405771)     Gray{Float64}(0.362565)
#  Gray{Float64}(0.386488)  Gray{Float64}(0.385859)     Gray{Float64}(0.339177)
#  Gray{Float64}(0.364266)  Gray{Float64}(0.358819)     Gray{Float64}(0.323565)
#  Gray{Float64}(0.337798)  Gray{Float64}(0.33516)   …  Gray{Float64}(0.304155)
#  Gray{Float64}(0.32369)   Gray{Float64}(0.316212)     Gray{Float64}(0.293739)
#  Gray{Float64}(0.313111)  Gray{Float64}(0.305649)     Gray{Float64}(0.281027)
#  Gray{Float64}(0.301954)  Gray{Float64}(0.293282)     Gray{Float64}(0.265285)
#  Gray{Float64}(0.289492)  Gray{Float64}(0.284311)     Gray{Float64}(0.244948)

# %%
PCA_STACK = zeros( 80, 80, size(F.vectors,2) )

for i = 1:size(normed_faces, 2)
    PCA_STACK[:,:,i] = get_max_1(back_to_2d(F.vectors[:,i], im_dims))
end

size(PCA_STACK)
# Out:
# (80, 80, 6400)

# %%
k = 98

img1 = testimage("mandrill") # 512*512 RGB image
img2 = testimage("blobs") # 254*256 Gray image

set = [imresize(img2, im_dims), PCA_STACK[:,:,6400]]

for i = 1:k
    set = append!(set, [PCA_STACK[:,:,6400-i]] )
end

# Gray.(PCA_STACK[:,:,6396])

# %%
# mosaicview(imresize(img2, im_dims), PCA_STACK[:,:,6400])
mosaicview(set, nrow=10,ncol=10)
# Out:
# 800×800 MosaicView{RGBX{Float64},4,Base.ReshapedArray{RGBX{Float64},4,PaddedView{RGBX{Float64},3,Tuple{Base.OneTo{Int64},Base.OneTo{Int64},Base.OneTo{Int64}},MappedArrays.MappedArray{RGBX{Float64},3,Array{Any,3},MappedArrays.var"#2#4"{RGBX{Float64}},MappedArrays.var"#3#5"{Any}}},Tuple{Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64},Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64}}}}:
#  RGBX{Float64}(0.847059,0.847059,0.847059)  …  RGBX{Float64}(0.0109093,0.0109093,0.0109093)
#  RGBX{Float64}(0.894118,0.894118,0.894118)     RGBX{Float64}(0.175163,0.175163,0.175163)
#  RGBX{Float64}(0.811765,0.811765,0.811765)     RGBX{Float64}(0.0923113,0.0923113,0.0923113)
#  RGBX{Float64}(0.835294,0.835294,0.835294)     RGBX{Float64}(-0.15704,-0.15704,-0.15704)
#  RGBX{Float64}(0.878431,0.878431,0.878431)     RGBX{Float64}(-0.22069,-0.22069,-0.22069)
#  RGBX{Float64}(0.788235,0.788235,0.788235)  …  RGBX{Float64}(0.0246318,0.0246318,0.0246318)
#  RGBX{Float64}(0.564706,0.564706,0.564706)     RGBX{Float64}(-0.0411795,-0.0411795,-0.0411795)
#  RGBX{Float64}(0.443137,0.443137,0.443137)     RGBX{Float64}(-0.330185,-0.330185,-0.330185)
#  RGBX{Float64}(0.411765,0.411765,0.411765)     RGBX{Float64}(-0.286378,-0.286378,-0.286378)
#  RGBX{Float64}(0.435294,0.435294,0.435294)     RGBX{Float64}(-0.255724,-0.255724,-0.255724)
#  RGBX{Float64}(0.596078,0.596078,0.596078)  …  RGBX{Float64}(-0.287074,-0.287074,-0.287074)
#  RGBX{Float64}(0.819608,0.819608,0.819608)     RGBX{Float64}(-0.297777,-0.297777,-0.297777)
#  RGBX{Float64}(0.933333,0.933333,0.933333)     RGBX{Float64}(-0.412111,-0.412111,-0.412111)
#  ⋮                                          ⋱
#  RGBX{Float64}(0.821968,0.821968,0.821968)     RGBX{Float64}(0.0802411,0.0802411,0.0802411)
#  RGBX{Float64}(0.857441,0.857441,0.857441)     RGBX{Float64}(-0.024851,-0.024851,-0.024851)
#  RGBX{Float64}(0.878872,0.878872,0.878872)  …  RGBX{Float64}(-0.116758,-0.116758,-0.116758)
#  RGBX{Float64}(0.892139,0.892139,0.892139)     RGBX{Float64}(-0.0873299,-0.0873299,-0.0873299)
#  RGBX{Float64}(0.899254,0.899254,0.899254)     RGBX{Float64}(-0.0537707,-0.0537707,-0.0537707)
#  RGBX{Float64}(0.894396,0.894396,0.894396)     RGBX{Float64}(-0.0648971,-0.0648971,-0.0648971)
#  RGBX{Float64}(0.90202,0.90202,0.90202)        RGBX{Float64}(-0.0250888,-0.0250888,-0.0250888)
#  RGBX{Float64}(0.889052,0.889052,0.889052)  …  RGBX{Float64}(0.0420178,0.0420178,0.0420178)
#  RGBX{Float64}(0.87813,0.87813,0.87813)        RGBX{Float64}(0.120069,0.120069,0.120069)
#  RGBX{Float64}(0.866542,0.866542,0.866542)     RGBX{Float64}(0.168188,0.168188,0.168188)
#  RGBX{Float64}(0.852493,0.852493,0.852493)     RGBX{Float64}(0.212264,0.212264,0.212264)
#  RGBX{Float64}(0.846613,0.846613,0.846613)     RGBX{Float64}(0.30958,0.30958,0.30958)
